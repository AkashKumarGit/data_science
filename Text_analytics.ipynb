# %%
# NLP (Natural Language Processing)
# !pip install nltk

# %% [markdown]
# # Tokenization
# The process of breaking down a text paragraph into smaller chunks such as words or sentence is called Tokenization

# %%
# Sentence Tokenizer
import nltk
from nltk.tokenize import sent_tokenize
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard. This route connects you directly to the destination"""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
tokenized_text[2]
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard.", 'This route connects you directly to the destination']
# 'The sky is pinkish-blue.'

# %%
# Word Tokenizer
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.', 'This', 'route', 'connects', 'you', 'directly', 'to', 'the', 'destination']

# %%
# Frequency Distribution
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 32 samples and 39 outcomes>

# %%
fdist.most_common(5)
# Out:
# [('is', 3), ('.', 3), (',', 2), ('you', 2), ('The', 2)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %% [markdown]
# # Stopwords
# Stopwords considered as noise in the text. Text may contain stop words such as is, am, are, this, a, an, the, etc

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {"you're", 'her', 'few', 'into', 'ma', 'our', 'aren', "wouldn't", 'hers', 'himself', 'under', 'mustn', 'by', 've', 'd', 'been', 'during', "hasn't", 'at', 'she', "shouldn't", 'after', 'being', 'but', 'for', 'i', "mightn't", 'each', 'yourselves', 'hasn', 'did', 'do', 'here', 'isn', 'again', 'a', "hadn't", 'some', 'against', 'such', 'am', 'out', 'won', 'he', 'your', 'so', 'than', 'you', 'was', 'just', 'don', 'an', 'which', 'off', 'with', 'doesn', 'on', 'weren', 'these', 'of', 'as', 'where', "couldn't", 'shouldn', 'wasn', 'their', 'same', 'ourselves', 'up', 't', "didn't", "you'd", 'below', 'when', 'through', 'both', 'more', 'between', 'not', "aren't", 'before', 'this', 'were', 'my', "mustn't", 'his', 'those', 'how', 'if', 'about', 'own', "it's", "shan't", "won't", "haven't", 'had', 'are', "doesn't", 's', 'whom', "weren't", "you've", 'very', 'having', 'will', 'any', "should've", 'we', 'mightn', 'further', 'theirs', 'it', 'over', 'yourself', 'be', 'them', 'too', 'to', 'myself', 'other', 'y
# ...

# %%
# Removing Stopwords
filtered_sent=[] # ['how','are','you','doing',]
for w in tokenized_word:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_word)
print("Filtered words:",filtered_sent)
# Out:
# Tokenized Sentence: ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.', 'This', 'route', 'connects', 'you', 'directly', 'to', 'the', 'destination']
# Filtered words: ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard', '.', 'This', 'route', 'connects', 'directly', 'destination']

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud,ImageColorGenerator
# Converts element of list to a text
new_text = " ".join(t for t in filtered_sent)
print (filtered_sent)
print (new_text)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard', '.', 'This', 'route', 'connects', 'directly', 'destination']
# Hello Mr. Smith , today ? The weather great , city awesome . The sky pinkish-blue . You n't eat cardboard . This route connects directly destination

# %%
# Generate a word cloud image
wordcloud = WordCloud(background_color="black").generate(new_text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Stemming
# Stemming is a process of linguistic normalization, which reduces words to their root word

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)

calculate - verb
calculator - noun
calculat
# Out:
# Filtered Sentence: ['Hello', 'Mr.', 'Smith', ',', 'today', '?', 'The', 'weather', 'great', ',', 'city', 'awesome', '.', 'The', 'sky', 'pinkish-blue', '.', 'You', "n't", 'eat', 'cardboard', '.', 'This', 'route', 'connects', 'directly', 'destination']
# Stemmed Sentence: ['hello', 'mr.', 'smith', ',', 'today', '?', 'the', 'weather', 'great', ',', 'citi', 'awesom', '.', 'the', 'sky', 'pinkish-blu', '.', 'you', "n't", 'eat', 'cardboard', '.', 'thi', 'rout', 'connect', 'directli', 'destin']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fda1c4b99600> in <module>
#      12 print("Stemmed Sentence:",stemmed_words)
#      13
# ---> 14 calculate - verb
#      15 calculator - noun
#      16 calculat
#
# NameError: name 'calculate' is not defined

# %% [markdown]
# # Lemmatization
# Lemmatization reduces words to their base word, which is linguistically correct lemmas. It transforms root word with the use of vocabulary and morphological analysis.

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "tried"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))

# %% [markdown]
# # POS Tagging
# The primary target of Part-of-Speech(POS) tagging is to identify the grammatical group of a given word.
# Whether it is a NOUN, PRONOUN, ADJECTIVE, VERB, ADVERBS, etc. based on the context.

# %%
sent = "Albert Einstein was born in Ulm, Germany in 1879."

# %%
tokens=word_tokenize(sent)
print(tokens)

# %%
# List for POS tags : https://cs.nyu.edu/grishman/jet/guide/PennPOS.html
nltk.pos_tag(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cc38e93d79db> in <module>
#       1 # List for POS tags : https://cs.nyu.edu/grishman/jet/guide/PennPOS.html
# ----> 2 nltk.pos_tag(tokens)
#
# NameError: name 'tokens' is not defined

# %% [markdown]
# # Sentiment Analysis

# %%
# Import pandas
import pandas as pd

# %% [markdown]
# This data has 5 sentiment labels:
#
# 0 - negative 1 - somewhat negative 2 - neutral 3 - somewhat positive 4 - positive

# %%
data=pd.read_csv('/Users/akash/Downloads/train.tsv', sep='\t')

# %%
data['Phrase']
# Out:
# 0         A series of escapades demonstrating the adage ...
# 1         A series of escapades demonstrating the adage ...
# 2                                                  A series
# 3                                                         A
# 4                                                    series
#                                 ...
# 156055                                            Hearst 's
# 156056                            forced avuncular chortles
# 156057                                   avuncular chortles
# 156058                                            avuncular
# 156059                                             chortles
# Name: Phrase, Length: 156060, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PhraseId    156060 non-null  int64
#  1   SentenceId  156060 non-null  int64
#  2   Phrase      156060 non-null  object
#  3   Sentiment   156060 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB

# %%
data.Sentiment.value_counts()
# Out:
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: Sentiment, dtype: int64

# %%
import matplotlib.pyplot as plt
Sentiment_count=data.groupby('Sentiment').count()
plt.bar(Sentiment_count.index.values, Sentiment_count['Phrase'])
plt.xlabel('Review Sentiments')
plt.ylabel('Number of Review')
plt.show()

# %% [markdown]
# # Feature Generation using Bag of Words
# BoW(Bag of Words) converts text into the matrix of occurrence of words within a document.
# This model concerns about whether given words occurred or not in the document.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,2),tokenizer = token.tokenize)
text_counts= cv.fit_transform(data['Phrase'])

# %%
text_counts
# Out:
# <156060x75748 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1048547 stored elements in Compressed Sparse Row format>

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_counts, data['Sentiment'], test_size=0.3, random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.6104062540048699

# %% [markdown]
# # Feature Generation using TF-IDF

# %% [markdown]
# # Term Frequency (TF)
# In Term Frequency(TF), you just count the number of words occurred in each document.
# The main issue with this Term Frequency is that it will give more weight to longer documents

# %%
# This is a good book and I will read this book
Term frequecncy:
good = 1
book = 2
and = 1


1.I love dogs 
2. I hate dogs and knitting
3. Knitting is my hobby and passion
TF = 
idf('Knitting') = log (3/2)
TF-IDF = TF* IDF
# Out:
#   File "<ipython-input-23-80f90d2b42dc>", line 2
#     Term frequecncy:
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Inverse Document Frequency (IDF)
# IDF(Inverse Document Frequency) measures the amount of information a given word provides across the document.
# IDF is the logarithmically scaled inverse ratio of the number of documents that contain the word and the total number of documents.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# TF-IDF(Term Frequency-Inverse Document Frequency) normalizes the document term matrix.
# It is the product of TF and IDF. Word with high tf-idf in a document,
# it is most of the times occurred in given documents and must be absent in the other documents.
# So the words must be a signature word.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
text_tf= tf.fit_transform(data['Phrase'])

# %%
text_tf
# Out:
# <156060x15240 sparse matrix of type '<class 'numpy.float64'>'
# 	with 972099 stored elements in Compressed Sparse Row format>

# %%
# Split train and test set (TF-IDF)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_tf, data['Sentiment'], test_size=0.3, random_state=123)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.5865265496176684

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
predicted = clf.predict(X_test)
print(confusion_matrix(y_test, predicted))
print(classification_report(y_test, predicted))
# Out:
# [[   72   790  1213    35     0]
#  [   36  2003  5865   177     0]
#  [   12   994 21440  1450    24]
#  [    0    93  5961  3810    65]
#  [    0    11   981  1651   135]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.03      0.06      2110
#            1       0.51      0.25      0.33      8081
#            2       0.60      0.90      0.72     23920
#            3       0.53      0.38      0.45      9929
#            4       0.60      0.05      0.09      2778
#
#     accuracy                           0.59     46818
#    macro avg       0.57      0.32      0.33     46818
# weighted avg       0.57      0.59      0.53     46818

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 263 kB/s eta 0:00:01
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047105 sha256=856bc85384d6d8cd773fc35ecde6b43a3f83a7c30d350881983e471c2acc884b
#   Stored in directory: /private/var/folders/z7/486snry52yl2bgr53sj0s8g00000gn/T/pip-ephem-wheel-cache-vuoffiag/wheels/ee/4d/f7/563214122be1540b5f9197b52cb3ddb9c4a8070808b22d5a84
# Successfully built en-core-web-sm
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# !python -m spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ====================== Installed models (spaCy v2.3.2) ======================
# ℹ spaCy installation:
# /opt/anaconda3/lib/python3.8/site-packages/spacy
#
# TYPE      NAME             MODEL            VERSION
# package   en-core-web-sm   en_core_web_sm   2.3.1   ✔

# %%
import spacy
# Load the installed model "en_core_web_sm"
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp("This is a text")

# %%
doc = nlp("This is a text")
# Token texts
[token.text for token in doc]
# ['This', 'is', 'a', 'text']
# Out:
# ['This', 'is', 'a', 'text']

# %%
doc = nlp("Mahatma Gandhi founded Google")
# Text and label of named entity span
[(ent.text, ent.label_) for ent in doc.ents]
# [('Larry Page', 'PERSON'), ('Google', 'ORG')]
# Out:
# [('Mahatma Gandhi', 'PERSON')]

# %%
from spacy import displacy
doc = nlp("This is a sentence")
displacy.render(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4522944c545c41f8bdab723f56a527ba-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc = nlp("Larry Page founded Google")
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Larry Page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  founded Google</div></span>
